# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://www.timeout.com/film/best-movies-of-all-time'

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
content = soup.find('div', class_='_zoneItems_882m9_1 zoneItems')
# content.find_all('article')[0].find('h3').text.split(':')[1].strip()
content = content.find_all('article')
content
# Out:
# [<article class="tile _article_kc5qn_1" data-testid="tile-zone-large-list_testID"><div class="_imageContainer_kc5qn_33"><a class="tileImageLink" data-data-layer='{"triggerOn":0,"payload":{"category":"GP Engagement","label":"in content","action":"link - internal"}}' data-testid="tile-link_testID" href="https://www.timeout.com/movies/2001-a-space-odyssey" rel="" target="_self"><div class="_imageWrap_kc5qn_229"><img alt="2001: A Space Odyssey (1968)" class="lazyload _image_kc5qn_33 aspect-ratio-4-3" data-sizes="auto" data-srcset="https://media.timeout.com/images/105455969/380/285/image.jpg 380w,https://media.timeout.com/images/105455969/750/562/image.jpg 750w,https://media.timeout.com/images/105455969/1024/768/image.jpg 1024w,https://media.timeout.com/images/105455969/1372/1029/image.jpg 1372w,https://media.timeout.com/images/105455969/1536/1152/image.jpg 1536w,https://media.timeout.com/images/105455969/1920/1440/image.jpg 1920w" data-testid="responsive-image_testID" height="562" src="h
# ...

# %%
movies = [i.find('h3').text.replace('\xa0','').split('.')[1] for i in content]
movies
# Out:
# ['2001: A Space Odyssey (1968)',
#  'The Godfather (1972)',
#  'Citizen Kane (1941)',
#  'Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)',
#  'Raiders of the Lost Ark (1981)',
#  'La Dolce Vita (1960)',
#  'Seven Samurai (1954)',
#  'In the Mood for Love (2000)',
#  'There Will Be Blood (2007)',
#  'Singin’ in the Rain (1952)',
#  'Goodfellas (1990)',
#  'North by Northwest (1959)',
#  'Mulholland Drive (2001)',
#  'Bicycle Thieves (1948)',
#  'The Dark Knight (2008)',
#  'City Lights (1931)',
#  'Grand Illusion (1937)',
#  'His Girl Friday (1940)',
#  'The Red Shoes (1948)',
#  'Vertigo (1958)',
#  'Beau Travail (1999)',
#  'The Searchers (1956)',
#  'Persona (1966)',
#  'Do the Right Thing (1989)',
#  'Rashomon (1950)',
#  'The Rules of the Game (1939)',
#  'Jaws (1975)',
#  'Double Indemnity (1944)',
#  'The 400 Blows (1959)',
#  'Star Wars (1977)',
#  'The Passion of Joan of Arc (1928)',
#  'Once Upon a Time in the West (1968)',
#  'Alien (1979)',
# ...

# %%
first_movie = [i.split(':')[1].strip() for i in movies if i == movies[0]]
movies[0] = first_movie[0]
movies
# Out:
# ['A Space Odyssey (1968)',
#  'The Godfather (1972)',
#  'Citizen Kane (1941)',
#  'Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles (1975)',
#  'Raiders of the Lost Ark (1981)',
#  'La Dolce Vita (1960)',
#  'Seven Samurai (1954)',
#  'In the Mood for Love (2000)',
#  'There Will Be Blood (2007)',
#  'Singin’ in the Rain (1952)',
#  'Goodfellas (1990)',
#  'North by Northwest (1959)',
#  'Mulholland Drive (2001)',
#  'Bicycle Thieves (1948)',
#  'The Dark Knight (2008)',
#  'City Lights (1931)',
#  'Grand Illusion (1937)',
#  'His Girl Friday (1940)',
#  'The Red Shoes (1948)',
#  'Vertigo (1958)',
#  'Beau Travail (1999)',
#  'The Searchers (1956)',
#  'Persona (1966)',
#  'Do the Right Thing (1989)',
#  'Rashomon (1950)',
#  'The Rules of the Game (1939)',
#  'Jaws (1975)',
#  'Double Indemnity (1944)',
#  'The 400 Blows (1959)',
#  'Star Wars (1977)',
#  'The Passion of Joan of Arc (1928)',
#  'Once Upon a Time in the West (1968)',
#  'Alien (1979)',
#  'Tokyo Story (1951)',
# ...

# %%
import re
mylist = movies # init the list
year = []
for y in mylist:
    match = re.match(r'.*([1-3][0-9]{3})', y)
    if match is not None:
        year.append(match.group(1))
    else:
        year.append('no year')

# %%
year
# Out:
# ['1968',
#  '1972',
#  '1941',
#  '1975',
#  '1981',
#  '1960',
#  '1954',
#  '2000',
#  '2007',
#  '1952',
#  '1990',
#  '1959',
#  '2001',
#  '1948',
#  '2008',
#  '1931',
#  '1937',
#  '1940',
#  '1948',
#  '1958',
#  '1999',
#  '1956',
#  '1966',
#  '1989',
#  '1950',
#  '1939',
#  '1975',
#  '1944',
#  '1959',
#  '1977',
#  '1928',
#  '1968',
#  '1979',
#  '1951',
#  '1994',
#  '1998',
#  '1962',
#  '1960',
#  '1954',
#  '1966',
#  '1964',
#  '1974',
#  '1957',
#  '2003',
#  '1976',
#  '2001',
#  '1968',
#  '1925',
#  '1936',
#  '1960',
#  'no year',
#  '1931',
#  'no year',
#  '1972',
#  '1945',
#  '1922',
#  '1980',
#  '2013',
#  '2015',
#  '1979',
#  '2005',
#  '1933',
#  '1999',
#  '1976',
#  '1959',
#  '1926',
#  '2004',
#  '1974',
#  '1985',
#  '1995',
#  '1980',
#  '1995',
#  '1977',
#  '1974',
#  '1977',
#  '1959',
#  '1927',
#  '1941',
#  '1984',
#  '1934',
#  '1988',
#  '1970',
#  '1982',
#  '1991',
#  '1975',
#  '1980',
#  '1995',
#  '1972',
#  '1966',
#  '1988',
# ...

# %%
movies_list = []
for i in range(len(movies)):
    if i in [50, 52, 95]:
        movies_list.append(movies[i])
        print(i,movies[i])
        continue
    else:
        name = movies[i].replace(str([movies[i].split()[-1]][0]),'').strip()
        movies_list.append(name)
        print(i,name)
# Out:
# 0 A Space Odyssey
# 1 The Godfather
# 2 Citizen Kane
# 3 Jeanne Dielman, 23, Quai du Commerce, 1080 Bruxelles
# 4 Raiders of the Lost Ark
# 5 La Dolce Vita
# 6 Seven Samurai
# 7 In the Mood for Love
# 8 There Will Be Blood
# 9 Singin’ in the Rain
# 10 Goodfellas
# 11 North by Northwest
# 12 Mulholland Drive
# 13 Bicycle Thieves
# 14 The Dark Knight
# 15 City Lights
# 16 Grand Illusion
# 17 His Girl Friday
# 18 The Red Shoes
# 19 Vertigo
# 20 Beau Travail
# 21 The Searchers
# 22 Persona
# 23 Do the Right Thing
# 24 Rashomon
# 25 The Rules of the Game
# 26 Jaws
# 27 Double Indemnity
# 28 The 400 Blows
# 29 Star Wars
# 30 The Passion of Joan of Arc
# 31 Once Upon a Time in the West
# 32 Alien
# 33 Tokyo Story
# 34 Pulp Fiction
# 35 The Truman Show
# 36 Lawrence of Arabia
# 37 Psycho
# 38 Sansho the Bailiff
# 39 Andrei Rublev
# 40 The Umbrellas of Cherbourg
# 41 Chinatown
# 42 The Seventh Seal
# 43 Lost in Translation
# 44 Taxi Driver
# 45 Spirited Away
# 46 Night of the Living Dead
# ...

# %%
len(movies_list)
# Out:
# 100

# %%
len(year)
# Out:
# 100

# %%
data = {
    'Rank': range(1,101),
    'Movies': movies_list,
    'Release_Year': year
}

# %%
df = pd.DataFrame(data)

# %%
df[df['Release_Year'] == 'no year']

df.iloc[[50,52,95],:]
# Out:
#     Rank             Movies Release_Year
# 50    51                 Dr      no year
# 52    53       Blade Runner      no year
# 95    96  The Cabinet of Dr      no year

# %%
for i in df.iterrows():
    if i[0] in [50,52,95]:
        print(i[1].Movies)
# Out:
# Dr
# Blade Runner
# The Cabinet of Dr

# %%
df.loc[(df['Release_Year'] == 'no year') & (df['Movies'] == 'Blade Runner')]['Release_Year'] = '1982'

# %%
df[df.iloc[:,-1] == 'no year'].Release_Year.replace('no year','1982')
# Out:
# 50    1982
# 52    1982
# 95    1982
# Name: Release_Year, dtype: object

# %%
df.Release_Year = df.Release_Year.replace('no year', '1982')
df
# Out:
#     Rank                                             Movies Release_Year
# 0      1                                    A Space Odyssey         1968
# 1      2                                      The Godfather         1972
# 2      3                                       Citizen Kane         1941
# 3      4  Jeanne Dielman, 23, Quai du Commerce, 1080 Bru...         1975
# 4      5                            Raiders of the Lost Ark         1981
# ..   ...                                                ...          ...
# 95    96                                  The Cabinet of Dr         1982
# 96    97                                          Nashville         1975
# 97    98                                     Don’t Look Now         1973
# 98    99                                   Bonnie and Clyde         1967
# 99   100                                            Get Out         2017
#
# [100 rows x 3 columns]

# %%
df[df['Release_Year'] == 'no year']
# Out:
# Empty DataFrame
# Columns: [Rank, Movies, Release_Year]
# Index: []

# %%
df[df['Movies'] == 'Dr']
# Out:
#     Rank Movies Release_Year
# 50    51     Dr         1982

# %%
df[df['Release_Year'] == 'no year'] = '1982'

# %%
df
# Out:
#    Rank                                             Movies Release_Year
# 0     1                                    A Space Odyssey         1968
# 1     2                                      The Godfather         1972
# 2     3                                       Citizen Kane         1941
# 3     4  Jeanne Dielman, 23, Quai du Commerce, 1080 Bru...         1975
# 4     5                            Raiders of the Lost Ark         1981
# ..  ...                                                ...          ...
# 95   96                                  The Cabinet of Dr         1982
# 96   97                                          Nashville         1975
# 97   98                                     Don’t Look Now         1973
# 98   99                                   Bonnie and Clyde         1967
# 99  100                                            Get Out         2017
#
# [100 rows x 3 columns]

# %%
df[df['Movies'] == 'The Cabinet of Dr']
# Out:
#    Rank             Movies Release_Year
# 95   96  The Cabinet of Dr         1982

# %% [markdown]
# df

# %%
df.to_csv('Best_Movies.csv',index=False)

# %%
pd.read_csv('Best_Movies.csv',index_col=[0])
# Out:
#                                                  Movies  Release_Year
# Rank
# 1                                       A Space Odyssey          1968
# 2                                         The Godfather          1972
# 3                                          Citizen Kane          1941
# 4     Jeanne Dielman, 23, Quai du Commerce, 1080 Bru...          1975
# 5                               Raiders of the Lost Ark          1981
# ...                                                 ...           ...
# 96                                    The Cabinet of Dr          1982
# 97                                            Nashville          1975
# 98                                       Don’t Look Now          1973
# 99                                     Bonnie and Clyde          1967
# 100                                             Get Out          2017
#
# [100 rows x 2 columns]
